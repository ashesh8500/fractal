# %%
from analysis import main

main()
# Out:
# Discovered strategies: ['bollinger_attractiveness', 'ml_attractiveness', 'Momentum']
# /Users/asheshkaji/projects/fractal/portfolio_lib/portfolio_lib/services/strategy/bollinger.py:179: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   vol_change = vol.pct_change().iloc[-1].replace([np.inf, -np.inf], np.nan)
# /Users/asheshkaji/projects/fractal/portfolio_lib/portfolio_lib/services/strategy/bollinger.py:186: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   momentum.pct_change().iloc[-1].replace([np.inf, -np.inf], np.nan)
# ...

# %%
# Let's run the improved analysis with better allocation plots and trade signals
from analysis_improved import run_enhanced_analysis
run_enhanced_analysis()
# Out:
# Discovered strategies: ['bollinger_attractiveness', 'ml_attractiveness', 'Momentum']
#
# Running backtest for bollinger_attractiveness...
# /Users/asheshkaji/projects/fractal/portfolio_lib/portfolio_lib/services/strategy/bollinger.py:179: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#
# /Users/asheshkaji/projects/fractal/portfolio_lib/portfolio_lib/services/strategy/bollinger.py:186: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#
# /Users/asheshkaji/projects/fractal/portfolio_lib/portfolio_lib/services/strategy/bollinger.py:179: FutureWarning:
#
# ...
